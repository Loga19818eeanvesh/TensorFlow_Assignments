# %% [markdown]
# <a href="https://colab.research.google.com/github/Loga19818eeanvesh/TensorFlow_Assignments/blob/main/c1w1_l2_multi_output_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow==2.2.0
# Out:
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2 MB)
#      |████████████████████████████████| 516.2 MB 4.3 kB/s
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 58.7 MB/s
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      |████████████████████████████████| 454 kB 58.1 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.0)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 44.8 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.13.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.43.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.21.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.4.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.37.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.17.3)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.11.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.2.0)
# Installing collected packages: tensorflow-estimator, tensorboard, h5py, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# Successfully installed gast-0.3.3 h5py-2.10.0 tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=50, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/50
# 62/62 [==============================] - 1s 10ms/step - loss: 257.0305 - y1_output_loss: 124.0276 - y2_output_loss: 133.0029 - y1_output_root_mean_squared_error: 11.1368 - y2_output_root_mean_squared_error: 11.5327 - val_loss: 32.9970 - val_y1_output_loss: 13.6428 - val_y2_output_loss: 19.3542 - val_y1_output_root_mean_squared_error: 3.6936 - val_y2_output_root_mean_squared_error: 4.3993
# Epoch 2/50
# 62/62 [==============================] - 0s 4ms/step - loss: 38.9135 - y1_output_loss: 13.7180 - y2_output_loss: 25.1956 - y1_output_root_mean_squared_error: 3.7038 - y2_output_root_mean_squared_error: 5.0195 - val_loss: 72.6981 - val_y1_output_loss: 16.5744 - val_y2_output_loss: 56.1237 - val_y1_output_root_mean_squared_error: 4.0712 - val_y2_output_root_mean_squared_error: 7.4916
# Epoch 3/50
# 62/62 [==============================] - 0s 4ms/step - loss: 28.3484 - y1_output_loss: 10.9445 - y2_output_loss: 17.4039 - y1_output_root_mean_squared_error: 3.3082 - y2_output_root_mean_squared_error: 4.1718 - val_loss: 20.1637 - val_y1_output_loss: 9.9088 - val_y2_output_loss: 10.2549 - val_y1_output_root_mean_squared_error: 3.1478 - val_y2_output_root_mean_squared_error: 3.2023
# Epoch 4/50
# 62/62 [==============================] - 0s 3ms/step - loss: 24.4300 - y1_output_loss: 9.9236 - y2_output_loss: 14.5065 - y1_output_root_mean_squared_error: 3.1502 - y2_output_root_mean_squared_error: 3.8087 - val_loss: 21.1671 - val_y1_output_loss: 8.7166 - val_y2_output_loss: 12.4505 - val_y1_output_root_mean_squared_error: 2.9524 - val_y2_output_root_mean_squared_error: 3.5285
# Epoch 5/50
# 62/62 [==============================] - 0s 4ms/step - loss: 24.4460 - y1_output_loss: 9.5553 - y2_output_loss: 14.8908 - y1_output_root_mean_squared_error: 3.0912 - y2_output_root_mean_squared_error: 3.8589 - val_loss: 23.3765 - val_y1_output_loss: 9.5465 - val_y2_output_loss: 13.8301 - val_y1_output_root_mean_squared_error: 3.0897 - val_y2_output_root_mean_squared_error: 3.7189
# Epoch 6/50
# 62/62 [==============================] - 0s 2ms/step - loss: 22.2792 - y1_output_loss: 9.0117 - y2_output_loss: 13.2674 - y1_output_root_mean_squared_error: 3.0020 - y2_output_root_mean_squared_error: 3.6424 - val_loss: 19.5293 - val_y1_output_loss: 9.0122 - val_y2_output_loss: 10.5171 - val_y1_output_root_mean_squared_error: 3.0020 - val_y2_output_root_mean_squared_error: 3.2430
# Epoch 7/50
# 62/62 [==============================] - 0s 2ms/step - loss: 22.5406 - y1_output_loss: 8.9436 - y2_output_loss: 13.5971 - y1_output_root_mean_squared_error: 2.9906 - y2_output_root_mean_squared_error: 3.6874 - val_loss: 19.2283 - val_y1_output_loss: 7.6009 - val_y2_output_loss: 11.6273 - val_y1_output_root_mean_squared_error: 2.7570 - val_y2_output_root_mean_squared_error: 3.4099
# Epoch 8/50
# 62/62 [==============================] - 0s 2ms/step - loss: 28.5126 - y1_output_loss: 9.7622 - y2_output_loss: 18.7503 - y1_output_root_mean_squared_error: 3.1245 - y2_output_root_mean_squared_error: 4.3302 - val_loss: 17.9674 - val_y1_output_loss: 7.4520 - val_y2_output_loss: 10.5154 - val_y1_output_root_mean_squared_error: 2.7298 - val_y2_output_root_mean_squared_error: 3.2428
# Epoch 9/50
# 62/62 [==============================] - 0s 2ms/step - loss: 23.1099 - y1_output_loss: 8.6362 - y2_output_loss: 14.4737 - y1_output_root_mean_squared_error: 2.9387 - y2_output_root_mean_squared_error: 3.8044 - val_loss: 19.0851 - val_y1_output_loss: 9.7884 - val_y2_output_loss: 9.2968 - val_y1_output_root_mean_squared_error: 3.1286 - val_y2_output_root_mean_squared_error: 3.0491
# Epoch 10/50
# 62/62 [==============================] - 0s 2ms/step - loss: 21.9469 - y1_output_loss: 8.4428 - y2_output_loss: 13.5040 - y1_output_root_mean_squared_error: 2.9057 - y2_output_root_mean_squared_error: 3.6748 - val_loss: 27.1265 - val_y1_output_loss: 8.4605 - val_y2_output_loss: 18.6660 - val_y1_output_root_mean_squared_error: 2.9087 - val_y2_output_root_mean_squared_error: 4.3204
# Epoch 11/50
# 62/62 [==============================] - 0s 2ms/step - loss: 26.6055 - y1_output_loss: 9.6528 - y2_output_loss: 16.9527 - y1_output_root_mean_squared_error: 3.1069 - y2_output_root_mean_squared_error: 4.1174 - val_loss: 18.5994 - val_y1_output_loss: 8.7096 - val_y2_output_loss: 9.8899 - val_y1_output_root_mean_squared_error: 2.9512 - val_y2_output_root_mean_squared_error: 3.1448
# Epoch 12/50
# 62/62 [==============================] - 0s 2ms/step - loss: 19.3822 - y1_output_loss: 7.8583 - y2_output_loss: 11.5239 - y1_output_root_mean_squared_error: 2.8033 - y2_output_root_mean_squared_error: 3.3947 - val_loss: 28.0486 - val_y1_output_loss: 10.1472 - val_y2_output_loss: 17.9014 - val_y1_output_root_mean_squared_error: 3.1855 - val_y2_output_root_mean_squared_error: 4.2310
# Epoch 13/50
# 62/62 [==============================] - 0s 2ms/step - loss: 25.2126 - y1_output_loss: 9.0005 - y2_output_loss: 16.2121 - y1_output_root_mean_squared_error: 3.0001 - y2_output_root_mean_squared_error: 4.0264 - val_loss: 17.4177 - val_y1_output_loss: 7.2824 - val_y2_output_loss: 10.1353 - val_y1_output_root_mean_squared_error: 2.6986 - val_y2_output_root_mean_squared_error: 3.1836
# Epoch 14/50
# 62/62 [==============================] - 0s 2ms/step - loss: 18.9405 - y1_output_loss: 7.3928 - y2_output_loss: 11.5477 - y1_output_root_mean_squared_error: 2.7190 - y2_output_root_mean_squared_error: 3.3982 - val_loss: 102.5149 - val_y1_output_loss: 24.9029 - val_y2_output_loss: 77.6120 - val_y1_output_root_mean_squared_error: 4.9903 - val_y2_output_root_mean_squared_error: 8.8098
# Epoch 15/50
# 62/62 [==============================] - 0s 2ms/step - loss: 21.6800 - y1_output_loss: 8.1555 - y2_output_loss: 13.5245 - y1_output_root_mean_squared_error: 2.8558 - y2_output_root_mean_squared_error: 3.6776 - val_loss: 20.2549 - val_y1_output_loss: 6.7979 - val_y2_output_loss: 13.4570 - val_y1_output_root_mean_squared_error: 2.6073 - val_y2_output_root_mean_squared_error: 3.6684
# Epoch 16/50
# 62/62 [==============================] - 0s 2ms/step - loss: 17.8860 - y1_output_loss: 7.0963 - y2_output_loss: 10.7897 - y1_output_root_mean_squared_error: 2.6639 - y2_output_root_mean_squared_error: 3.2848 - val_loss: 21.8108 - val_y1_output_loss: 8.6535 - val_y2_output_loss: 13.1573 - val_y1_output_root_mean_squared_error: 2.9417 - val_y2_output_root_mean_squared_error: 3.6273
# Epoch 17/50
# 62/62 [==============================] - 0s 2ms/step - loss: 17.2693 - y1_output_loss: 6.8738 - y2_output_loss: 10.3955 - y1_output_root_mean_squared_error: 2.6218 - y2_output_root_mean_squared_error: 3.2242 - val_loss: 13.5059 - val_y1_output_loss: 5.9374 - val_y2_output_loss: 7.5685 - val_y1_output_root_mean_squared_error: 2.4367 - val_y2_output_root_mean_squared_error: 2.7511
# Epoch 18/50
# 62/62 [==============================] - 0s 2ms/step - loss: 17.6868 - y1_output_loss: 6.9327 - y2_output_loss: 10.7541 - y1_output_root_mean_squared_error: 2.6330 - y2_output_root_mean_squared_error: 3.2793 - val_loss: 12.7727 - val_y1_output_loss: 5.8295 - val_y2_output_loss: 6.9432 - val_y1_output_root_mean_squared_error: 2.4144 - val_y2_output_root_mean_squared_error: 2.6350
# Epoch 19/50
# 62/62 [==============================] - 0s 2ms/step - loss: 21.1362 - y1_output_loss: 7.5140 - y2_output_loss: 13.6221 - y1_output_root_mean_squared_error: 2.7412 - y2_output_root_mean_squared_error: 3.6908 - val_loss: 14.3468 - val_y1_output_loss: 6.7482 - val_y2_output_loss: 7.5986 - val_y1_output_root_mean_squared_error: 2.5977 - val_y2_output_root_mean_squared_error: 2.7566
# Epoch 20/50
# 62/62 [==============================] - 0s 2ms/step - loss: 18.5801 - y1_output_loss: 6.6604 - y2_output_loss: 11.9197 - y1_output_root_mean_squared_error: 2.5808 - y2_output_root_mean_squared_error: 3.4525 - val_loss: 14.6356 - val_y1_output_loss: 6.6487 - val_y2_output_loss: 7.9869 - val_y1_output_root_mean_squared_error: 2.5785 - val_y2_output_root_mean_squared_error: 2.8261
# Epoch 21/50
# 62/62 [==============================] - 0s 2ms/step - loss: 17.9815 - y1_output_loss: 6.7399 - y2_output_loss: 11.2416 - y1_output_root_mean_squared_error: 2.5961 - y2_output_root_mean_squared_error: 3.3528 - val_loss: 15.8272 - val_y1_output_loss: 6.5790 - val_y2_output_loss: 9.2482 - val_y1_output_root_mean_squared_error: 2.5650 - val_y2_output_root_mean_squared_error: 3.0411
# Epoch 22/50
# 62/62 [==============================] - 0s 2ms/step - loss: 18.9840 - y1_output_loss: 6.8337 - y2_output_loss: 12.1503 - y1_output_root_mean_squared_error: 2.6141 - y2_output_root_mean_squared_error: 3.4857 - val_loss: 11.7857 - val_y1_output_loss: 5.1929 - val_y2_output_loss: 6.5928 - val_y1_output_root_mean_squared_error: 2.2788 - val_y2_output_root_mean_squared_error: 2.5676
# Epoch 23/50
# 62/62 [==============================] - 0s 2ms/step - loss: 17.0856 - y1_output_loss: 6.3441 - y2_output_loss: 10.7416 - y1_output_root_mean_squared_error: 2.5187 - y2_output_root_mean_squared_error: 3.2774 - val_loss: 12.7249 - val_y1_output_loss: 6.1846 - val_y2_output_loss: 6.5403 - val_y1_output_root_mean_squared_error: 2.4869 - val_y2_output_root_mean_squared_error: 2.5574
# Epoch 24/50
# 62/62 [==============================] - 0s 2ms/step - loss: 15.4365 - y1_output_loss: 6.0759 - y2_output_loss: 9.3607 - y1_output_root_mean_squared_error: 2.4649 - y2_output_root_mean_squared_error: 3.0595 - val_loss: 12.5583 - val_y1_output_loss: 5.1451 - val_y2_output_loss: 7.4132 - val_y1_output_root_mean_squared_error: 2.2683 - val_y2_output_root_mean_squared_error: 2.7227
# Epoch 25/50
# 62/62 [==============================] - 0s 2ms/step - loss: 14.0700 - y1_output_loss: 5.3163 - y2_output_loss: 8.7537 - y1_output_root_mean_squared_error: 2.3057 - y2_output_root_mean_squared_error: 2.9587 - val_loss: 41.0917 - val_y1_output_loss: 11.2195 - val_y2_output_loss: 29.8722 - val_y1_output_root_mean_squared_error: 3.3496 - val_y2_output_root_mean_squared_error: 5.4655
# Epoch 26/50
# 62/62 [==============================] - 0s 2ms/step - loss: 13.8331 - y1_output_loss: 5.1938 - y2_output_loss: 8.6393 - y1_output_root_mean_squared_error: 2.2790 - y2_output_root_mean_squared_error: 2.9393 - val_loss: 61.4360 - val_y1_output_loss: 17.0197 - val_y2_output_loss: 44.4163 - val_y1_output_root_mean_squared_error: 4.1255 - val_y2_output_root_mean_squared_error: 6.6646
# Epoch 27/50
# 62/62 [==============================] - 0s 2ms/step - loss: 15.1940 - y1_output_loss: 5.6039 - y2_output_loss: 9.5901 - y1_output_root_mean_squared_error: 2.3673 - y2_output_root_mean_squared_error: 3.0968 - val_loss: 17.9256 - val_y1_output_loss: 6.6947 - val_y2_output_loss: 11.2309 - val_y1_output_root_mean_squared_error: 2.5874 - val_y2_output_root_mean_squared_error: 3.3513
# Epoch 28/50
# 62/62 [==============================] - 0s 2ms/step - loss: 13.5595 - y1_output_loss: 5.1708 - y2_output_loss: 8.3887 - y1_output_root_mean_squared_error: 2.2739 - y2_output_root_mean_squared_error: 2.8963 - val_loss: 11.3355 - val_y1_output_loss: 4.8583 - val_y2_output_loss: 6.4772 - val_y1_output_root_mean_squared_error: 2.2042 - val_y2_output_root_mean_squared_error: 2.5450
# Epoch 29/50
# 62/62 [==============================] - 0s 2ms/step - loss: 17.4053 - y1_output_loss: 5.8244 - y2_output_loss: 11.5809 - y1_output_root_mean_squared_error: 2.4134 - y2_output_root_mean_squared_error: 3.4031 - val_loss: 15.8009 - val_y1_output_loss: 5.2820 - val_y2_output_loss: 10.5189 - val_y1_output_root_mean_squared_error: 2.2983 - val_y2_output_root_mean_squared_error: 3.2433
# Epoch 30/50
# 62/62 [==============================] - 0s 2ms/step - loss: 12.9699 - y1_output_loss: 4.8083 - y2_output_loss: 8.1616 - y1_output_root_mean_squared_error: 2.1928 - y2_output_root_mean_squared_error: 2.8568 - val_loss: 9.3130 - val_y1_output_loss: 4.1903 - val_y2_output_loss: 5.1227 - val_y1_output_root_mean_squared_error: 2.0470 - val_y2_output_root_mean_squared_error: 2.2633
# Epoch 31/50
# 62/62 [==============================] - 0s 2ms/step - loss: 12.1047 - y1_output_loss: 4.2709 - y2_output_loss: 7.8338 - y1_output_root_mean_squared_error: 2.0666 - y2_output_root_mean_squared_error: 2.7989 - val_loss: 9.1356 - val_y1_output_loss: 3.9474 - val_y2_output_loss: 5.1881 - val_y1_output_root_mean_squared_error: 1.9868 - val_y2_output_root_mean_squared_error: 2.2777
# Epoch 32/50
# 62/62 [==============================] - 0s 4ms/step - loss: 11.9451 - y1_output_loss: 4.2217 - y2_output_loss: 7.7234 - y1_output_root_mean_squared_error: 2.0547 - y2_output_root_mean_squared_error: 2.7791 - val_loss: 21.7492 - val_y1_output_loss: 4.8185 - val_y2_output_loss: 16.9307 - val_y1_output_root_mean_squared_error: 2.1951 - val_y2_output_root_mean_squared_error: 4.1147
# Epoch 33/50
# 62/62 [==============================] - 0s 3ms/step - loss: 10.2271 - y1_output_loss: 3.8765 - y2_output_loss: 6.3506 - y1_output_root_mean_squared_error: 1.9689 - y2_output_root_mean_squared_error: 2.5200 - val_loss: 21.4023 - val_y1_output_loss: 4.6017 - val_y2_output_loss: 16.8005 - val_y1_output_root_mean_squared_error: 2.1452 - val_y2_output_root_mean_squared_error: 4.0988
# Epoch 34/50
# 62/62 [==============================] - 0s 2ms/step - loss: 11.6117 - y1_output_loss: 4.0947 - y2_output_loss: 7.5170 - y1_output_root_mean_squared_error: 2.0235 - y2_output_root_mean_squared_error: 2.7417 - val_loss: 12.3772 - val_y1_output_loss: 4.0702 - val_y2_output_loss: 8.3070 - val_y1_output_root_mean_squared_error: 2.0175 - val_y2_output_root_mean_squared_error: 2.8822
# Epoch 35/50
# 62/62 [==============================] - 0s 2ms/step - loss: 11.8301 - y1_output_loss: 3.8471 - y2_output_loss: 7.9830 - y1_output_root_mean_squared_error: 1.9614 - y2_output_root_mean_squared_error: 2.8254 - val_loss: 9.5993 - val_y1_output_loss: 3.5413 - val_y2_output_loss: 6.0580 - val_y1_output_root_mean_squared_error: 1.8818 - val_y2_output_root_mean_squared_error: 2.4613
# Epoch 36/50
# 62/62 [==============================] - 0s 2ms/step - loss: 11.3482 - y1_output_loss: 3.8501 - y2_output_loss: 7.4981 - y1_output_root_mean_squared_error: 1.9622 - y2_output_root_mean_squared_error: 2.7383 - val_loss: 7.2948 - val_y1_output_loss: 2.8258 - val_y2_output_loss: 4.4690 - val_y1_output_root_mean_squared_error: 1.6810 - val_y2_output_root_mean_squared_error: 2.1140
# Epoch 37/50
# 62/62 [==============================] - 0s 2ms/step - loss: 8.9921 - y1_output_loss: 3.2238 - y2_output_loss: 5.7683 - y1_output_root_mean_squared_error: 1.7955 - y2_output_root_mean_squared_error: 2.4017 - val_loss: 13.5799 - val_y1_output_loss: 5.1001 - val_y2_output_loss: 8.4797 - val_y1_output_root_mean_squared_error: 2.2584 - val_y2_output_root_mean_squared_error: 2.9120
# Epoch 38/50
# 62/62 [==============================] - 0s 2ms/step - loss: 9.2793 - y1_output_loss: 3.3750 - y2_output_loss: 5.9044 - y1_output_root_mean_squared_error: 1.8371 - y2_output_root_mean_squared_error: 2.4299 - val_loss: 7.6949 - val_y1_output_loss: 2.8970 - val_y2_output_loss: 4.7979 - val_y1_output_root_mean_squared_error: 1.7021 - val_y2_output_root_mean_squared_error: 2.1904
# Epoch 39/50
# 62/62 [==============================] - 0s 3ms/step - loss: 8.4455 - y1_output_loss: 3.1169 - y2_output_loss: 5.3286 - y1_output_root_mean_squared_error: 1.7655 - y2_output_root_mean_squared_error: 2.3084 - val_loss: 10.1742 - val_y1_output_loss: 3.4528 - val_y2_output_loss: 6.7214 - val_y1_output_root_mean_squared_error: 1.8582 - val_y2_output_root_mean_squared_error: 2.5926
# Epoch 40/50
# 62/62 [==============================] - 0s 2ms/step - loss: 8.8929 - y1_output_loss: 3.2421 - y2_output_loss: 5.6508 - y1_output_root_mean_squared_error: 1.8006 - y2_output_root_mean_squared_error: 2.3771 - val_loss: 9.2960 - val_y1_output_loss: 4.0361 - val_y2_output_loss: 5.2599 - val_y1_output_root_mean_squared_error: 2.0090 - val_y2_output_root_mean_squared_error: 2.2935
# Epoch 41/50
# 62/62 [==============================] - 0s 2ms/step - loss: 10.1835 - y1_output_loss: 3.4492 - y2_output_loss: 6.7343 - y1_output_root_mean_squared_error: 1.8572 - y2_output_root_mean_squared_error: 2.5951 - val_loss: 6.7741 - val_y1_output_loss: 2.4783 - val_y2_output_loss: 4.2958 - val_y1_output_root_mean_squared_error: 1.5743 - val_y2_output_root_mean_squared_error: 2.0726
# Epoch 42/50
# 62/62 [==============================] - 0s 2ms/step - loss: 7.9490 - y1_output_loss: 2.8139 - y2_output_loss: 5.1351 - y1_output_root_mean_squared_error: 1.6775 - y2_output_root_mean_squared_error: 2.2661 - val_loss: 6.7299 - val_y1_output_loss: 2.5647 - val_y2_output_loss: 4.1652 - val_y1_output_root_mean_squared_error: 1.6015 - val_y2_output_root_mean_squared_error: 2.0409
# Epoch 43/50
# 62/62 [==============================] - 0s 2ms/step - loss: 8.6908 - y1_output_loss: 3.1184 - y2_output_loss: 5.5724 - y1_output_root_mean_squared_error: 1.7659 - y2_output_root_mean_squared_error: 2.3606 - val_loss: 6.5895 - val_y1_output_loss: 2.5889 - val_y2_output_loss: 4.0006 - val_y1_output_root_mean_squared_error: 1.6090 - val_y2_output_root_mean_squared_error: 2.0001
# Epoch 44/50
# 62/62 [==============================] - 0s 2ms/step - loss: 7.3534 - y1_output_loss: 2.5514 - y2_output_loss: 4.8020 - y1_output_root_mean_squared_error: 1.5973 - y2_output_root_mean_squared_error: 2.1913 - val_loss: 7.0963 - val_y1_output_loss: 2.5269 - val_y2_output_loss: 4.5695 - val_y1_output_root_mean_squared_error: 1.5896 - val_y2_output_root_mean_squared_error: 2.1376
# Epoch 45/50
# 62/62 [==============================] - 0s 2ms/step - loss: 7.5501 - y1_output_loss: 2.7260 - y2_output_loss: 4.8242 - y1_output_root_mean_squared_error: 1.6511 - y2_output_root_mean_squared_error: 2.1964 - val_loss: 13.2679 - val_y1_output_loss: 3.8726 - val_y2_output_loss: 9.3953 - val_y1_output_root_mean_squared_error: 1.9679 - val_y2_output_root_mean_squared_error: 3.0652
# Epoch 46/50
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7793 - y1_output_loss: 2.9196 - y2_output_loss: 5.8598 - y1_output_root_mean_squared_error: 1.7087 - y2_output_root_mean_squared_error: 2.4207 - val_loss: 22.0219 - val_y1_output_loss: 6.1002 - val_y2_output_loss: 15.9216 - val_y1_output_root_mean_squared_error: 2.4699 - val_y2_output_root_mean_squared_error: 3.9902
# Epoch 47/50
# 62/62 [==============================] - 0s 2ms/step - loss: 9.0022 - y1_output_loss: 2.9252 - y2_output_loss: 6.0770 - y1_output_root_mean_squared_error: 1.7103 - y2_output_root_mean_squared_error: 2.4652 - val_loss: 6.3989 - val_y1_output_loss: 2.2362 - val_y2_output_loss: 4.1628 - val_y1_output_root_mean_squared_error: 1.4954 - val_y2_output_root_mean_squared_error: 2.0403
# Epoch 48/50
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7175 - y1_output_loss: 2.7224 - y2_output_loss: 4.9951 - y1_output_root_mean_squared_error: 1.6500 - y2_output_root_mean_squared_error: 2.2350 - val_loss: 7.4645 - val_y1_output_loss: 2.5915 - val_y2_output_loss: 4.8730 - val_y1_output_root_mean_squared_error: 1.6098 - val_y2_output_root_mean_squared_error: 2.2075
# Epoch 49/50
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8811 - y1_output_loss: 2.5736 - y2_output_loss: 5.3075 - y1_output_root_mean_squared_error: 1.6042 - y2_output_root_mean_squared_error: 2.3038 - val_loss: 23.0566 - val_y1_output_loss: 7.6762 - val_y2_output_loss: 15.3804 - val_y1_output_root_mean_squared_error: 2.7706 - val_y2_output_root_mean_squared_error: 3.9218
# Epoch 50/50
# 62/62 [==============================] - 0s 2ms/step - loss: 8.7387 - y1_output_loss: 2.8913 - y2_output_loss: 5.8475 - y1_output_root_mean_squared_error: 1.7004 - y2_output_root_mean_squared_error: 2.4182 - val_loss: 6.0520 - val_y1_output_loss: 2.0673 - val_y2_output_loss: 3.9847 - val_y1_output_root_mean_squared_error: 1.4378 - val_y2_output_root_mean_squared_error: 1.9962

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 6.0520 - y1_output_loss: 2.0673 - y2_output_loss: 3.9847 - y1_output_root_mean_squared_error: 1.4378 - y2_output_root_mean_squared_error: 1.9962
# Loss = 6.051999092102051, Y1_loss = 2.067301034927368, Y1_mse = 1.437811255455017, Y2_loss = 3.9846982955932617, Y2_mse = 1.9961708784103394

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
